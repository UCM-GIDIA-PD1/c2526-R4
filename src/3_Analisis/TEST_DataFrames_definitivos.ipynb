# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
base_dir = Path().resolve().parents[1] # Nos situamos en la carpeta del proyecto
data_dir = base_dir / 'data/processed'

df_popularity = pd.read_parquet(Path(data_dir / 'popularidad.parquet'))
df_prices = pd.read_parquet(Path(data_dir / 'precios.parquet'))

# %%
df_popularity.head()

# %%
df_prices.head()
